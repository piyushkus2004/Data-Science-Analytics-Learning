# %%
import pandas as pd

# %%
s = pd.Series([71,67,89,56,89])

# %%
s
# Out:
# 0    71
# 1    67
# 2    89
# 3    56
# 4    89
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s2 = s = pd.Series([71,67,89,56,89], index=["Hari","Dev","Rev","Nick","Ken"])

# %%
s2
# Out:
# Hari    71
# Dev     67
# Rev     89
# Nick    56
# Ken     89
# dtype: int64

# %%
s2["Nick"]
# Out:
# np.int64(56)

# %%
# Data Frame

# %%
data = {
    "name" : ["Harkirat" , "Kunal" , "Raj"],
    "age" : [25 , 14 , 45],
    "City" : ["Delhi" , "Mumbai" , "banglore"],
    
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#        name  age      City
# 0  Harkirat   25     Delhi
# 1     Kunal   14    Mumbai
# 2       Raj   45  banglore

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)
