# %%
l = [2,34,23,3]

# %%
l[0]=456

# %%
l
# Out:
# [456, 34, 23, 3]

# %%
l.append(0)

# %%
l
# Out:
# [456, 34, 23, 3, 0]

# %%
l2 = [23,56]

# %%
l.extend(l2)

# %%
l
# Out:
# [456, 34, 23, 3, 0, 23, 56]

# %%
l.insert(2,300)

# %%
l
# Out:
# [456, 34, 300, 23, 3, 0, 23, 56]

# %%
l.append(9)

# %%
l
# Out:
# [456, 34, 300, 23, 3, 0, 23, 56, 9]

# %%
l.count(7)
# Out:
# 0

# %%
l.sort()

# %%
l
# Out:
# [0, 3, 9, 23, 23, 34, 56, 300, 456]

# %%
sorted(l) # returns the new list which is the sorted version of original list
# Out:
# [0, 3, 9, 23, 23, 34, 56, 300, 456]

# %%
y = [1 , 2 ,True , False ,[6,8]]  # nested loops

# %%
y
# Out:
# [1, 2, True, False, [6, 8]]

# %%
list1 =  [2,4,6]

# %%
list2 = [7,9,10]

# %%
list1 + list2
# Out:
# [2, 4, 6, 7, 9, 10]
