# %%
class Employee:
    company = "Dell"
    def __init__(self,name,salary):
        self.name = name
        self.salary = salary

    def printDetails(self):
        print(f"The company of {self.name} is {self.company} with salary $ {self.salary}")
e = Employee ("Piyush", 50000)
e.printDetails()
# Out:
# The company of Piyush is Dell with salary $ 50000
