# %%
b = set()

# %%
type(b)
# Out:
# set

# %%
s = {4,32,32,45,76,43,90,90,1,32}

# %%
s
# Out:
# {1, 4, 32, 43, 45, 76, 90}

# %%
s.add(17)

# %%
s
# Out:
# {1, 4, 17, 32, 43, 45, 76, 90}

# %%
s.remove(17)

# %%
s
# Out:
# {1, 4, 32, 43, 45, 76, 90}

# %%
s.remove(0)
# Out:
# ------------------------------------------------------------
# KeyError                   Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 s.remove(0)
#
# KeyError: 0

# %%
s
# Out:
# {1, 4, 32, 43, 45, 76, 90}

# %%
s.discard(0)

# %%
s
# Out:
# {1, 4, 32, 43, 45, 76, 90}

# %%
set1 = {1,2,3,4}
set2 = {3,4,5,6}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set2.union(set1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
sub = {1,2}

# %%
sub.issubset(set1)
# Out:
# True
