# %%
name = "Piyush"

# %%
name
# Out:
# 'Piyush'

# %%
name.upper
# Out:
# <function str.upper()>

# %%
name.upper()
# Out:
# 'PIYUSH'

# %%
name[0:4}
# Out:
#   Cell In[5], line 1
#     name[0:4}
#             ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '['

# %%
name[0:3]
# Out:
# 'Piy'

# %%
a=5
b=3

# %%
a-b
# Out:
# 2

# %%
a = 45

# %%
a +=4

# %%
a
# Out:
# 12

# %%
a
# Out:
# 12

# %%
c = 80

# %%
c += 5

# %%
c
# Out:
# 85
