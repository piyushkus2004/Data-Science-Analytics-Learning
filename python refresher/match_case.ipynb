# %%
code = 2000

# %%
match code :
    case 200:
        print("Response Ok")
    case 400:
        print("Bad Response")
    case 404:
        print("Not found")
    case _:
        print("Nothing matched")
print ("End of Program")
# Out:
# Nothing matched
# End of Program
