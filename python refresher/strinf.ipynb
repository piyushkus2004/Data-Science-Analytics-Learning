# %%
name = "Piyush"
age = 21
print("My name {} and I am {} yeras old".format(name,age))
# Out:
# My name Piyush and I am 21 yeras old

# %%
print(f"My name is {name} and I am {age} years old")
# Out:
# My name is Piyush and I am 21 years old

# %%
print(f"{'Python':<10}")  # Left-align
print(f"{'Python':>10}")  # Right-align
print(f"{'Python':^10}")  # Center-align
# Out:
# Python
#     Python
#   Python
