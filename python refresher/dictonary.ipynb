# %%
student = {
    "name" : "Alice",
    "age": 25,
    "grade" : "A"
}

# %%
student["name"]
# Out:
# 'Alice'

# %%
print(student["age"])
# Out:
# 25

# %%
student["age"] = 87

# %%
print(student)
# Out:
# {'name': 'Alice', 'age': 87, 'grade': 'A'}

# %%
student.update({"name": "Harry"})

# %%
student
# Out:
# {'name': 'Harry', 'age': 87, 'grade': 'A'}
