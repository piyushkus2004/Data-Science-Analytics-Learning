# %%
import numpy as np
myarr = np.array([[1,2,3] , [4,5,6] , [9,8,7] , [6,5,9]])

# %%
myarr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [9, 8, 7],
#        [6, 5, 9]])

# %%
flat = myarr.flatten()

# %%
flat
# Out:
# array([1, 2, 3, 4, 5, 6, 9, 8, 7, 6, 5, 9])

# %%
flat[:5]
# Out:
# array([1, 2, 3, 4, 5])

# %%
flat[5:]
# Out:
# array([6, 9, 8, 7, 6, 5, 9])

# %%
b = flat[3:7]

# %%
b
# Out:
# array([4, 5, 6, 9])

# %%
b[0] = 8967

# %%
b
# Out:
# array([8967,    5,    6,    9])

# %%
flat
# Out:
# array([   1,    2,    3, 8967,    5,    6,    9,    8,    7,    6,    5,
#           9])

# %%
arr = np.array([1,23,89,34,67,90])

# %%
arr[[1,4,3]]
# Out:
# array([23, 67, 34])

# %%
arr[arr>3]
# Out:
# array([23, 89, 34, 67, 90])
