# %%
import numpy as np

# %%
arr = np.array([3,5,6,8])

# %%
np.mean(arr)
# Out:
# np.float64(5.5)

# %%
np.prod(arr)
# Out:
# np.int64(720)

# %%
np.max(arr)
# Out:
# np.int64(8)

# %%
np.percentile(arr, 50)  # For the 50th percentile (median)
# Out:
# np.float64(5.5)

# %%
np.argmax(arr)
# Out:
# np.int64(3)

# %%
np.cumsum(arr)
# Out:
# array([ 3,  8, 14, 22])
